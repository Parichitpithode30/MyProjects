# %%
import pandas as pd
import seaborn as sns
import os

# %%
df= pd.read_csv('/Users/parichitpithode/Documents/New folder/Python/loan prediction.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.count
# Out:
# <bound method DataFrame.count of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.value_counts()
# Out:
# Loan_ID   Gender  Married  Dependents  Education     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# LP001003  Male    Yes      1           Graduate      No             4583             1508.0             128.0       360.0             1.0             Rural          N              1
# LP001005  Male    Yes      0           Graduate      Yes            3000             0.0                66.0        360.0             1.0             Urban          Y              1
# LP002347  Male    Yes      0           Graduate      No             3246             1417.0             138.0       360.0             1.0             Semiurban      Y              1
# LP002345  Male    Yes      0           Graduate      No             1025             2773.0             112.0       360.0             1.0             Rural          Y              1
# ...

# %%
df_dependents=df['Dependents'].value_counts()
df_dependents.plot.bar()
sns.barplot(x=df_dependents.index, y=df_dependents.values)

#for frequency count from the data directly
sns.catplot(x="Dependents", kind="count", data=df)

# %%
df['LoanAmount'].describe()
# Out:
# count    592.000000
# mean     146.412162
# std       85.587325
# min        9.000000
# 25%      100.000000
# 50%      128.000000
# 75%      168.000000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %%
df['LoanAmount'].isnull().sum()
# Out:
# 22

# %%
df['LoanAmount'].fillna(0, inplace=True)
df['LoanAmount'].mean()
# Out:
# 141.16612377850163

# %%
df['LoanAmount'].max()
# Out:
# 700.0

# %%
df['LoanAmount'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.distplot(df['LoanAmount'],bins=50)
# Out:
# /Users/parichitpithode/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LoanAmount', ylabel='Density'>

# %%
#Bivariate Analysis
Edu_Emp=pd.crosstab(df.Education,df.Self_Employed)
Edu_Emp.plot.bar(stacked=True)
#plt.tight_layout()
# Out:
# <AxesSubplot:xlabel='Education'>

# %%
#Correlation
df[['ApplicantIncome','LoanAmount']].corr()
data1=df[df['ApplicantIncome']<300000]
df[['ApplicantIncome','LoanAmount']].corr()
sns.regplot(data1['ApplicantIncome'],df['LoanAmount'])
# Out:
# /Users/parichitpithode/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
#Categorica([l $ Numeric
df['LoanAmount'].groupby([df['Education']]).mean()
sns.barplot(x='Education', y='LoanAmount',data=df)
sns.boxplot(x='Married',y='LoanAmount',data=df,hue='Education')
# Out:
# <AxesSubplot:xlabel='Married', ylabel='LoanAmount'>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import os

# %%
data= pd.read_csv('/Users/parichitpithode/Documents/New folder/Python/loan prediction.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data1= data.copy()

# %%
data1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
len(data1)
# Out:
# 614

# %%
data1.shape
# Out:
# (614, 13)

# %%
#drop rows
data1.dropna(inplace=True)
data1.dropna(subset=['LoanAmount'],inplace=True)

# %%
data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data1.fillna(0,inplace=True)

# %%
data1['LoanAmount'].fillna(0,inplace=True)

# %%
data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#mean
mean1= data1['LoanAmount'].mean()

# %%
data1['LoanAmount'].fillna(mean1, inplace= True)
mean1
# Out:
# 144.73541666666668

# %%
#Median
data['LoanAmount'].fillna(data1['LoanAmount'].median(),inplace=True)

# %%
#Feature Engineering 
data['TotalIncome']=data['ApplicantIncome']+data['CoapplicantIncome']
data['TotalIncome']
# Out:
# 0      5849.0
# 1      6091.0
# 2      3000.0
# 3      4941.0
# 4      6000.0
#         ...
# 609    2900.0
# 610    4106.0
# 611    8312.0
# 612    7583.0
# 613    4583.0
# Name: TotalIncome, Length: 614, dtype: float64

# %%
#Feature Scaling (data standardization)
data_scale= data[['ApplicantIncome', 'CoapplicantIncome','LoanAmount','Loan_Amount_Term']]

# %%
data_scale1= data_scale.fillna(0)
data_scale1
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 0               5849                0.0       128.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
# [614 rows x 4 columns]

# %%
#z=(x-mean)/std dev
sc= StandardScaler()

# %%
data2= sc.fit_transform(data_scale1)
data2
# Out:
# array([[ 0.07299082, -0.55448733, -0.21124125,  0.31416232],
#        [-0.13441195, -0.03873155, -0.21124125,  0.31416232],
#        [-0.39374734, -0.55448733, -0.94899647,  0.31416232],
#        ...,
#        [ 0.43717437, -0.47240418,  1.27616847,  0.31416232],
#        [ 0.35706382, -0.55448733,  0.49081614,  0.31416232],
#        [-0.13441195, -0.55448733, -0.15174486,  0.31416232]])

# %%
#data1= data.copy()
#data1['Married'].value_counts()
#mode2=data1['Married'].mode()
#data1['Married'].fillna(mode2[0],inplace=True)
data2= data1.copy()

# %%
#Basic update command
data2.loc[data2.Married=='No','Married']=0
data2.loc[data2.Married=='Yes','Married']=1

# %%
data2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male       1          1      Graduate            No
# 2    LP001005    Male       1          0      Graduate           Yes
# 3    LP001006    Male       1          0  Not Graduate            No
# 4    LP001008    Male       0          0      Graduate            No
# 5    LP001011    Male       1          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female       0          0      Graduate            No
# 610  LP002979    Male       1         3+      Graduate            No
# 611  LP002983    Male       1          1      Graduate            No
# 612  LP002984    Male       1          2      Graduate            No
# 613  LP002990  Female       0          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Dummy variable (One hot encoder)
dummies1= pd.get_dummies(data1, columns=['Education','Dependents'])
dummies2= pd.get_dummies(data1, columns=['Education','Dependents'],drop_first=True)

# %%
dummies1
# Out:
#       Loan_ID  Gender Married Self_Employed  ApplicantIncome  \
# 1    LP001003    Male     Yes            No             4583
# 2    LP001005    Male     Yes           Yes             3000
# 3    LP001006    Male     Yes            No             2583
# 4    LP001008    Male      No            No             6000
# 5    LP001011    Male     Yes           Yes             5417
# ..        ...     ...     ...           ...              ...
# 609  LP002978  Female      No            No             2900
# 610  LP002979    Male     Yes            No             4106
# 611  LP002983    Male     Yes            No             8072
# 612  LP002984    Male     Yes            No             7583
# 613  LP002990  Female      No           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# ...

# %%
dummies2
# Out:
#       Loan_ID  Gender Married Self_Employed  ApplicantIncome  \
# 1    LP001003    Male     Yes            No             4583
# 2    LP001005    Male     Yes           Yes             3000
# 3    LP001006    Male     Yes            No             2583
# 4    LP001008    Male      No            No             6000
# 5    LP001011    Male     Yes           Yes             5417
# ..        ...     ...     ...           ...              ...
# 609  LP002978  Female      No            No             2900
# 610  LP002979    Male     Yes            No             4106
# 611  LP002983    Male     Yes            No             8072
# 612  LP002984    Male     Yes            No             7583
# 613  LP002990  Female      No           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# ...
